# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %%
#feedback_sheet = pd.read_csv(r"C:\Users\abc\Desktop\feedback\feedback.csv")

passbook = pd.read_excel(r"C:\Users\abc\Desktop\Chetan PNB AC\Passbook.xlsx")

# %%
passbook.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2748 entries, 0 to 2747
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           2748 non-null   object
#  1   Instrument ID  0 non-null      float64
#  2   Amount         2748 non-null   float64
#  3   Type           2748 non-null   object
#  4   Balance        2748 non-null   object
#  5   Remarks        2748 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 128.9+ KB

# %%
int(passbook["Amount"].sum())
# Out:
# 2066474

# %%
 CR = passbook.loc[passbook['Type'] == "CR", 'Amount'].sum()

# %%
DR = passbook.loc[passbook["Type"] == "DR", "Amount"].sum()

# %%
#feedback_sheet = pd.read_csv(r"C:\Users\abc\Desktop\feedback\feedback.csv")

#passbook = pd.read_excel(r"C:\Users\abc\Desktop\Chetan PNB AC\PNBONE_mPassbook_22-6-2023_21-6-2024_0287XXXXXXXX2619.xlsx")

# %%
import os
import io
import msoffcrypto

# Import Passbook with Excel File And Password protector file open 

# Import Excel file 2023 - 24
#cdir = os.path.dirname(__file__)
fpath = os.path.join(r"C:\Users\abc\Desktop\Chetan PNB AC\PNBONE_mPassbook_22-6-2023_21-6-2024_0287XXXXXXXX2619.xlsx")
 
unlocked_file = io.BytesIO()
 
with open(fpath, "rb") as file:
    excel_file = msoffcrypto.OfficeFile(file)
    excel_file.load_key(password = "0287001500032619")
    excel_file.decrypt(unlocked_file)
 
df = pd.read_excel(unlocked_file)
#print(df)

#df.tail(20)

#df.head(25)

#df.head(25)

#df.iloc[18:]
# Useful data chunk
pas_23 = df.iloc[18:-10]

# Reset index
pas_23 = pas_23.reset_index()

# Delete index file
pas_23 = pas_23.drop('index', axis=1)

# First row header in Column USe
headers = pas_23.iloc[0]
pas_23.columns = [headers] 
# First row delete
pas_23.drop(index=0, axis=0, inplace=True)
pas_23

pas_23 = pas_23.reset_index()

passbook_23_24 = pas_23.drop('index', axis=1)

passbook_23_24
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\abc\AppData\Local\Temp\ipykernel_3856\2636551287.py:46: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   passbook_23_24 = pas_23.drop('index', axis=1)
# 0          Date Instrument ID   Amount Type   Balance  \
# 0    21/06/2024           NaN    10.00   DR    361.29
# 1    21/06/2024           NaN    20.00   DR    371.29
# 2    21/06/2024           NaN     5.00   DR    391.29
# 3    21/06/2024           NaN    35.00   DR    396.29
# 4    21/06/2024           NaN    10.00   DR    431.29
# ..          ...           ...      ...  ...       ...
# 739  25/06/2023           NaN    30.00   DR  2,260.06
# 740  25/06/2023           NaN  2000.00   CR  2,290.06
# ...

# %%
import os
import io
import msoffcrypto

# Import Passbook with Excel File And Password protector file open 

# Import Excel file 2022 - 23
#cdir = os.path.dirname(__file__)
fpath = os.path.join(r"C:\Users\abc\Desktop\Chetan PNB AC\PNBONE_mPassbook_22-6-2022_21-6-2023_0287XXXXXXXX2619.xlsx")
 
unlocked_file = io.BytesIO()
 
with open(fpath, "rb") as file:
    excel_file = msoffcrypto.OfficeFile(file)
    excel_file.load_key(password = "0287001500032619")
    excel_file.decrypt(unlocked_file)
 
df = pd.read_excel(unlocked_file)
#print(df)

#df.tail(20)

#df.head(25)

#df.head(25)

#df.iloc[18:]
# Useful data chunk
pas = df.iloc[18:-10]

# Reset index
pas = pas.reset_index()

# Delete index file
pas = pas.drop('index', axis=1)

# First row header in Column USe
headers = pas.iloc[0]
pas.columns = [headers] 
# First row delete
pas.drop(index=0, axis=0, inplace=True)
pas

pas = pas.reset_index()

passbook_22_23 = pas.drop('index', axis=1)

passbook_22_23
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_3856\1902098825.py:46: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   passbook_22_23 = pas.drop('index', axis=1)
# 0          Date Instrument ID   Amount Type   Balance  \
# 0    20/06/2023           NaN    10.00   DR    339.06
# 1    20/06/2023           NaN   550.00   DR    349.06
# 2    20/06/2023           NaN   550.00   CR    899.06
# 3    20/06/2023           NaN    20.00   DR    349.06
# 4    20/06/2023           NaN     7.00   DR    369.06
# ..          ...           ...      ...  ...       ...
# 482  12/07/2022           NaN  1000.00   DR      3.01
# 483  11/07/2022           NaN     1.00   DR  1,003.01
# 484  11/07/2022           NaN  1000.00   CR  1,004.01
# 485  01/07/2022           NaN     1.00   DR      4.01
# 486  22/06/2022           NaN   190.00   DR      5.01
#
# 0                                              Remarks
# ...

# %%
passbook_23_24["Amount"] =  passbook_23_24["Amount"].astype(str)

passbook_23_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Date,)           744 non-null    object
#  1   (Instrument ID,)  0 non-null      object
#  2   (Amount,)         744 non-null    object
#  3   (Type,)           744 non-null    object
#  4   (Balance,)        744 non-null    object
#  5   (Remarks,)        744 non-null    object
# dtypes: object(6)
# memory usage: 35.0+ KB

# %%
passbook_23_24["Amount"] = passbook_23_24["Amount"].astype(str).astype(float)
#passbook_23_24["Balance"] = passbook_23_24["Balance"].astype(str).astype(float)

#passbook_23["Balance"].astype(str).astype(float)

passbook_23_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Date,)           744 non-null    object
#  1   (Instrument ID,)  0 non-null      object
#  2   (Amount,)         744 non-null    float64
#  3   (Type,)           744 non-null    object
#  4   (Balance,)        744 non-null    object
#  5   (Remarks,)        744 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 35.0+ KB

# %%
import os
import io
import msoffcrypto

# Import Passbook with Excel File And Password protector file open 

# Import Excel file 2021 - 22
#cdir = os.path.dirname(__file__)
fpath = os.path.join(r"C:\Users\abc\Desktop\Chetan PNB AC\PNBONE_mPassbook_22-6-2021_21-6-2022_0287XXXXXXXX2619.xlsx")
 
unlocked_file = io.BytesIO()
 
with open(fpath, "rb") as file:
    excel_file = msoffcrypto.OfficeFile(file)
    excel_file.load_key(password = "0287001500032619")
    excel_file.decrypt(unlocked_file)
 
df = pd.read_excel(unlocked_file)
#print(df)

#df.tail(20)

#df.head(25)

#df.head(25)

#df.iloc[18:]
# Useful data chunk
pas = df.iloc[18:-10]

# Reset index
pas = pas.reset_index()

# Delete index file
pas = pas.drop('index', axis=1)

# First row header in Column USe
headers = pas.iloc[0]
pas.columns = [headers] 
# First row delete
pas.drop(index=0, axis=0, inplace=True)
pas

pas = pas.reset_index()

passbook_21_22 = pas.drop('index', axis=1)

passbook_21_22
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\abc\AppData\Local\Temp\ipykernel_3856\3928373344.py:46: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   passbook_21_22 = pas.drop('index', axis=1)
# 0          Date Instrument ID   Amount Type   Balance  \
# 0    21/06/2022           NaN    24.78   DR    195.01
# 1    21/06/2022           NaN   500.00   DR    219.79
# 2    19/06/2022           NaN   239.00   DR    719.79
# 3    18/06/2022           NaN    24.78   DR    958.79
# 4    18/06/2022           NaN  2000.00   DR    983.57
# ..          ...           ...      ...  ...       ...
# 188  06/07/2021           NaN    20.00   CR    763.29
# 189  06/07/2021           NaN   303.00   DR    743.29
# ...

# %%
import os
import io
import msoffcrypto

# Import Passbook with Excel File And Password protector file open 

# Import Excel file 2020 - 21
#cdir = os.path.dirname(__file__)
fpath = os.path.join(r"C:\Users\abc\Desktop\Chetan PNB AC\PNBONE_mPassbook_22-6-2020_21-6-2021_0287XXXXXXXX2619.xlsx")
 
unlocked_file = io.BytesIO()
 
with open(fpath, "rb") as file:
    excel_file = msoffcrypto.OfficeFile(file)
    excel_file.load_key(password = "0287001500032619")
    excel_file.decrypt(unlocked_file)
 
df = pd.read_excel(unlocked_file)
#print(df)

#df.tail(20)

#df.head(25)

#df.head(25)

#df.iloc[18:]
# Useful data chunk
pas = df.iloc[18:-10]

# Reset index
pas = pas.reset_index()

# Delete index file
pas = pas.drop('index', axis=1)

# First row header in Column USe
headers = pas.iloc[0]
pas.columns = [headers] 
# First row delete
pas.drop(index=0, axis=0, inplace=True)
pas

pas = pas.reset_index()

passbook_20_21 = pas.drop('index', axis=1)

passbook_20_21
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\abc\AppData\Local\Temp\ipykernel_3856\3505260638.py:46: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   passbook_20_21 = pas.drop('index', axis=1)
# 0          Date Instrument ID   Amount Type    Balance  \
# 0    21/06/2021           NaN    11.00   DR      61.29
# 1    21/06/2021           NaN   400.00   DR      72.29
# 2    20/06/2021           NaN    49.25   DR     472.29
# 3    19/06/2021           NaN  2035.00   DR     521.54
# 4    19/06/2021           NaN  2000.00   CR   2,556.54
# ..          ...           ...      ...  ...        ...
# 237  23/06/2020           NaN  9990.00   CR  10,000.48
# 238  23/06/2020           NaN    10.00   CR      10.48
# ...

# %%
import os
import io
import msoffcrypto

# Import Passbook with Excel File And Password protector file open 

# Import Excel file 2019 - 20
#cdir = os.path.dirname(__file__)
fpath = os.path.join(r"C:\Users\abc\Desktop\Chetan PNB AC\PNBONE_mPassbook_22-6-2019_21-6-2020_0287XXXXXXXX2619.xlsx")
 
unlocked_file = io.BytesIO()
 
with open(fpath, "rb") as file:
    excel_file = msoffcrypto.OfficeFile(file)
    excel_file.load_key(password = "0287001500032619")
    excel_file.decrypt(unlocked_file)
 
df = pd.read_excel(unlocked_file)
#print(df)

#df.tail(20)

#df.head(25)

#df.head(25)

#df.iloc[18:]
# Useful data chunk
pas = df.iloc[18:-10]

# Reset index
pas = pas.reset_index()

# Delete index file
pas = pas.drop('index', axis=1)

# First row header in Column USe
headers = pas.iloc[0]
pas.columns = [headers] 
# First row delete
pas.drop(index=0, axis=0, inplace=True)
pas

pas = pas.reset_index()

passbook_19_20 = pas.drop('index', axis=1)

passbook_19_20
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\abc\AppData\Local\Temp\ipykernel_3856\1055937573.py:46: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   passbook_19_20 = pas.drop('index', axis=1)
# 0          Date Instrument ID   Amount Type   Balance  \
# 0    21/06/2020           NaN  3550.00   DR      1.48
# 1    21/06/2020           NaN    50.00   CR  3,551.48
# 2    21/06/2020           NaN  3500.00   CR  3,501.48
# 3    19/05/2020           NaN   200.00   DR      1.48
# 4    19/05/2020           NaN   200.00   CR    201.48
# ..          ...           ...      ...  ...       ...
# 636  23/06/2019           NaN    20.00   DR    176.26
# 637  23/06/2019           NaN    23.60   DR    196.26
# ...

# %%
import os
import io
import msoffcrypto

# Import Passbook with Excel File And Password protector file open 

# Import Excel file 2018 - 19
#cdir = os.path.dirname(__file__)
fpath = os.path.join(r"C:\Users\abc\Desktop\Chetan PNB AC\PNBONE_mPassbook_22-6-2018_21-6-2019_0287XXXXXXXX2619.xlsx")
 
unlocked_file = io.BytesIO()
 
with open(fpath, "rb") as file:
    excel_file = msoffcrypto.OfficeFile(file)
    excel_file.load_key(password = "0287001500032619")
    excel_file.decrypt(unlocked_file)
 
df = pd.read_excel(unlocked_file)
#print(df)

#df.tail(20)

#df.head(25)

#df.head(25)

#df.iloc[18:]
# Useful data chunk
pas = df.iloc[18:-10]

# Reset index
pas = pas.reset_index()

# Delete index file
pas = pas.drop('index', axis=1)

# First row header in Column USe
headers = pas.iloc[0]
pas.columns = [headers] 
# First row delete
pas.drop(index=0, axis=0, inplace=True)
pas

pas = pas.reset_index()

passbook_18_19 = pas.drop('index', axis=1)

passbook_18_19
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\abc\AppData\Local\Temp\ipykernel_3856\1574010562.py:46: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   passbook_18_19 = pas.drop('index', axis=1)
# 0          Date Instrument ID   Amount Type   Balance  \
# 0    18/06/2019           NaN    20.00   DR      4.86
# 1    18/06/2019           NaN    20.00   CR     24.86
# 2    18/06/2019           NaN    23.60   DR      4.86
# 3    18/06/2019           NaN   100.00   DR     28.46
# 4    18/06/2019           NaN    14.00   CR    128.46
# ..          ...           ...      ...  ...       ...
# 436  22/06/2018           NaN    23.60   DR  1,175.00
# 437  22/06/2018           NaN   300.00   DR  1,198.60
# ...

# %%
passbook_18_19.tail()
# Out:
# 0          Date Instrument ID   Amount Type   Balance  \
# 436  22/06/2018           NaN    23.60   DR  1,175.00
# 437  22/06/2018           NaN   300.00   DR  1,198.60
# 438  22/06/2018           NaN    23.60   DR  1,498.60
# 439  22/06/2018           NaN   700.00   DR  1,522.20
# 440  22/06/2018           NaN  2000.00   CR  2,222.20
#
# 0                                              Remarks
# 436       ATM WDR 817307025284 SBI VAIBHAV NAGAR
# 437       ATM WDR 817307025284 SBI VAIBHAV NAGAR
# 438       ATM WDR 817307025271 SBI VAIBHAV NAGAR
# 439       ATM WDR 817307025271 SBI VAIBHAV NAGAR
# 440  UPI/817307882516/P2A/9617560960/ASHVINI DO OMP...

# %%
import os
import io
import msoffcrypto

# Import Passbook with Excel File And Password protector file open 

# Import Excel file 2018 ( 1 Jan - 21 June )
#cdir = os.path.dirname(__file__)
fpath = os.path.join(r"C:\Users\abc\Desktop\Chetan PNB AC\PNBONE_mPassbook_1-1-2018_21-6-2018_0287XXXXXXXX2619.xlsx")
 
unlocked_file = io.BytesIO()
 
with open(fpath, "rb") as file:
    excel_file = msoffcrypto.OfficeFile(file)
    excel_file.load_key(password = "0287001500032619")
    excel_file.decrypt(unlocked_file)
 
df = pd.read_excel(unlocked_file)
#print(df)

#df.tail(20)

#df.head(25)

#df.head(25)

#df.iloc[18:]
# Useful data chunk
pas = df.iloc[18:-10]

# Reset index
pas = pas.reset_index()

# Delete index file
pas = pas.drop('index', axis=1)

# First row header in Column USe
headers = pas.iloc[0]
pas.columns = [headers] 
# First row delete
pas.drop(index=0, axis=0, inplace=True)
pas

pas = pas.reset_index()

passbook_18 = pas.drop('index', axis=1)

passbook_18
# Out:
# C:\Users\abc\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\abc\AppData\Local\Temp\ipykernel_3856\3646777022.py:46: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   passbook_18 = pas.drop('index', axis=1)
# 0         Date Instrument ID   Amount Type   Balance  \
# 0   17/06/2018           NaN    23.60   DR    222.20
# 1   17/06/2018           NaN  1500.00   DR    245.80
# 2   17/06/2018           NaN  1500.00   CR  1,745.80
# 3   15/06/2018           NaN    23.60   DR    245.80
# 4   15/06/2018           NaN   100.00   DR    269.40
# ..         ...           ...      ...  ...       ...
# 72  15/01/2018           NaN  2000.00   DR    612.00
# 73  14/01/2018           NaN  1000.00   CR  2,612.00
# ...

# %%
# All Dataframe Concate 
#pd.concat([s1, s2], ignore_index=True)
passbook_all = pd.concat([passbook_18, passbook_18_19, passbook_19_20, passbook_20_21, passbook_21_22, passbook_22_23, passbook_23_24])

# Index reset
passbook_all = passbook_all.reset_index()

# Index Delete
passbook_all = passbook_all.drop('index', axis=1)

# Column Delete
columns = ["Instrument ID"]
passbook_all.drop(columns, inplace=True, axis=1)
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_3856\4066875377.py:9: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   passbook_all = passbook_all.drop('index', axis=1)
# C:\Users\abc\AppData\Local\Temp\ipykernel_3856\4066875377.py:13: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   passbook_all.drop(columns, inplace=True, axis=1)

# %%
passbook_all
# Out:
# 0           Date   Amount Type   Balance  \
# 0     17/06/2018    23.60   DR    222.20
# 1     17/06/2018  1500.00   DR    245.80
# 2     17/06/2018  1500.00   CR  1,745.80
# 3     15/06/2018    23.60   DR    245.80
# 4     15/06/2018   100.00   DR    269.40
# ...          ...      ...  ...       ...
# 2820  25/06/2023     30.0   DR  2,260.06
# 2821  25/06/2023   2000.0   CR  2,290.06
# 2822  24/06/2023     32.0   DR    290.06
# 2823  24/06/2023     12.0   DR    322.06
# 2824  22/06/2023      5.0   DR    334.06
#
# 0                                               Remarks
# 0          ATM WDR 816817027794 VAIBHAV NAGAR CD
# 1          ATM WDR 816817027794 VAIBHAV NAGAR CD
# 2     UPI/816817016710/P2A/9617560960/ASHVINI DO OMP...
# 3          ATM WDR 816610015026 +BOB
# 4          ATM WDR 816610015026 +BOB
# ...                                                 ...
# 2820  UPI/317669336760/P2M/paytmqr281005050101m6sq7f...
# 2821  UPI/354256083227/P2V/ashvinimalviya@ybl/ASHVIN...
# ...

# %%
passbook_all.info()

passbook_all


file_name = 'Passbook_2018_2024.xlsx'
 
# saving the excel file
passbook_all.to_excel(file_name)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2825 entries, 0 to 2824
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   (Date,)     2825 non-null   object
#  1   (Amount,)   2825 non-null   object
#  2   (Type,)     2825 non-null   object
#  3   (Balance,)  2825 non-null   object
#  4   (Remarks,)  2825 non-null   object
# dtypes: object(5)
# memory usage: 110.5+ KB

# %%
passbook_all["Amount"] = passbook_all["Amount"].astype(float)

# %%
passbook_all["Remarks"] = passbook_all["Remarks"].astype("category")

# %%
passbook_all["Type"] = passbook_all["Type"].astype("category")

# %%
from datetime import date
#passbook_all["Date"] = passbook_all["Date"].astype({"date": date})

# %%
passbook_all["Balance"] = passbook_all["Balance"].astype("category")

# %%
passbook_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2825 entries, 0 to 2824
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   (Date,)     2825 non-null   object
#  1   (Amount,)   2825 non-null   float64
#  2   (Type,)     2825 non-null   category
#  3   (Balance,)  2825 non-null   category
#  4   (Remarks,)  2825 non-null   category
# dtypes: category(3), float64(1), object(1)
# memory usage: 227.5+ KB

# %%
passbook_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2825 entries, 0 to 2824
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   (Date,)     2825 non-null   object
#  1   (Amount,)   2825 non-null   float64
#  2   (Type,)     2825 non-null   category
#  3   (Balance,)  2825 non-null   object
#  4   (Remarks,)  2825 non-null   category
# dtypes: category(2), float64(1), object(2)
# memory usage: 160.7+ KB

# %%
passbook_all
# Out:
# 0           Date  Amount Type   Balance  \
# 0     17/06/2018    23.6   DR    222.20
# 1     17/06/2018  1500.0   DR    245.80
# 2     17/06/2018  1500.0   CR  1,745.80
# 3     15/06/2018    23.6   DR    245.80
# 4     15/06/2018   100.0   DR    269.40
# ...          ...     ...  ...       ...
# 2820  25/06/2023    30.0   DR  2,260.06
# 2821  25/06/2023  2000.0   CR  2,290.06
# 2822  24/06/2023    32.0   DR    290.06
# 2823  24/06/2023    12.0   DR    322.06
# 2824  22/06/2023     5.0   DR    334.06
#
# 0                                               Remarks
# 0          ATM WDR 816817027794 VAIBHAV NAGAR CD
# 1          ATM WDR 816817027794 VAIBHAV NAGAR CD
# 2     UPI/816817016710/P2A/9617560960/ASHVINI DO OMP...
# 3          ATM WDR 816610015026 +BOB
# 4          ATM WDR 816610015026 +BOB
# ...                                                 ...
# 2820  UPI/317669336760/P2M/paytmqr281005050101m6sq7f...
# 2821  UPI/354256083227/P2V/ashvinimalviya@ybl/ASHVIN...
# ...

# %%
passbook_stat = pd.read_excel(r"C:\Users\abc\Desktop\Chetan PNB AC\Passbook_2018_2024.xlsx")

# %%
passbook_stat["Type"] = passbook_stat["Type"].astype("category")

# %%
passbook_stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2826 entries, 0 to 2825
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   0        2825 non-null   float64
#  1   Date     2825 non-null   object
#  2   Amount   2825 non-null   float64
#  3   Type     2826 non-null   category
#  4   Balance  2825 non-null   object
#  5   Remarks  2825 non-null   object
# dtypes: category(1), float64(2), object(3)
# memory usage: 113.4+ KB
